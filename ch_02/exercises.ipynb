# %% [markdown]
# Exercises  from Chapter 2

# %%
import pandas as pd

# %%
df = pd.read_csv('data/parsed.csv') # MacOS

# %%
# 1. 95th percentile of earthquake magnitue in Japan using mb magnitude type.
filt =  (df['parsed_place'].str.contains('Japan')) & (df['magType'] == 'mb')                              
# df.loc[filt, 'mag'].describe(percentiles = [0.95]) # My attempt.
df.loc[filt, 'mag'].quantile(0.95) # Text book
# Out:
# 4.9

# %%
# 2. Percentage of quakes in indonisia that were acounpanied by tsunamis
# df['parsed_place'].sort_values().unique()
filt = df['parsed_place'] == 'Indonesia'
df.loc[filt, 'tsunami'].value_counts(normalize= True) # My attempt
f"{df.loc[filt, 'tsunami'].value_counts(normalize= True).iloc[1]:.2%}" # My attempt
# Out:
# '23.13%'

# %%
# 3. Summary Stats for quakes in Navada
df[df['parsed_place'] == 'Nevada'].describe()
# Out:
#              cdi        dmin       felt         gap         mag   mmi  \
# count  15.000000  681.000000  15.000000  681.000000  681.000000  1.00
# mean    2.440000    0.166199   2.400000  153.668120    0.500073  2.84
# std     0.501142    0.166228   4.626013   68.735302    0.696710   NaN
# min     2.000000    0.001000   1.000000   29.140000   -0.500000  2.84
# 25%     2.000000    0.053000   1.000000   97.380000   -0.100000  2.84
# 50%     2.200000    0.112000   1.000000  149.140000    0.400000  2.84
# 75%     2.900000    0.233000   1.000000  199.720000    0.900000  2.84
# max     3.300000    1.414000  19.000000  355.910000    2.900000  2.84
#
#               nst         rms         sig          time  tsunami     tz  \
# count  681.000000  681.000000  681.000000  6.810000e+02    681.0  681.0
# mean    12.618209    0.151986   10.970631  1.538314e+12      0.0 -480.0
# std      9.866963    0.084662   19.607150  5.965637e+08      0.0    0.0
# ...

# %%
# 4. Add column indicating whether Country or US State that is in the Ring of Fire.
rof_places = ['Alaska', 'Bolivia', 'California', 'Canada', 'Chile', 'Costa Rica', 'Ecuador', 'Fiji', 
              'Guatemala', 'Indonesia', 'Japan', 'Kermadec Islands', 'Mexico', 'New Zealand', 'Peru', 
              'Philippines', 'Russia' , 'Taiwan', 'Tonga', 'Washington'              ] 

filt = df['parsed_place'].isin(rof_places) | df['parsed_place'].str.contains('Antarctic')

df['in_rof'] = df['parsed_place'].isin(rof_places) | df['parsed_place'].str.contains('Antarctic')
df
# Out:
#      alert  cdi        code  \
# 0      NaN  NaN    37389218
# 1      NaN  NaN    37389202
# 2      NaN  4.4    37389194
# 3      NaN  NaN    37389186
# 4      NaN  NaN    73096941
# ...    ...  ...         ...
# 9327   NaN  NaN    73086771
# 9328   NaN  NaN    38063967
# 9329   NaN  NaN  2018261000
# 9330   NaN  NaN    38063959
# 9331   NaN  NaN    38063935
#
#                                                  detail      dmin  felt  \
# 0     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.008693   NaN
# 1     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.020030   NaN
# 2     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.021370  28.0
# 3     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.026180   NaN
# 4     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.077990   NaN
# ...                                                 ...       ...   ...
# 9327  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.018060   NaN
# ...

# %%
# 5. No. quakes in RoF and outside
df['in_rof'].value_counts()

# f"{df.loc[filt, 'tsunami'].value_counts(normalize= True).iloc[1]:.2%}" # My attempt
# Out:
# True     7188
# False    2144
# Name: in_rof, dtype: int64

# %%
# 6. No. tsunami in RoF and outside
sum(df['tsunami']*df['in_rof'])
# Out:
# 45
